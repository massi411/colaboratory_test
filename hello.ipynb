# %% [markdown]
# <a href="https://colab.research.google.com/github/massi411/colaboratory_test/blob/main/hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2.0*np.pi, 101)
y = np.sin(x)

plt.plot(x,y)
plt.show()
